# %% [markdown]
# # **Introduction**

# %% [markdown]
# For our final project we wanted to figure out what the best neighborhood was in Pittsburgh. We went onto WPRDC to gather 3 data sets to compare in order to answer our question. We believe that the friendliest neighborhood is considered the best neighborhood so that was the metric we used.

# %% [markdown]
# # **Metric**

# %% [markdown]
# Our overall metric for the project was friendliest. We broke that down into 3 submetrics. The first was amount of overdoeses in neighborhoods in Pittsburgh. We looked for neighborhoods with low overdoses because we thought that people overdosing was not very friendly. The second submetric was the amount of dog licenses in neighborhoods in Pittsburgh. We looked for neighborhoods with high dog lisences because we love dogs and think it makes neighborhoods more friendly. The last submetric we used was amount of private schools in neighborhoods in Pittsburgh. We looked for a low amount of private schools in a neighborhood because we think private school kids are stuck up which makes the neighborhood less friendly. The data set we used for drug overdoses was https://data.wprdc.org/dataset/allegheny-county-fatal-accidental-overdoses . The data set we used for dog lisences was https://data.wprdc.org/dataset/allegheny-county-dog-licenses . The data set we used for private schools was https://data.wprdc.org/dataset/allegheny-county-private-schools-locations .

# %% [markdown]
# ![Welcome](https://media.giphy.com/media/ZIkBzupEM9Ql9lWKQz/giphy.gif)

# %% [markdown]
# # **Data**

# %% [markdown]
# ![Data](https://media.giphy.com/media/LaVp0AyqR5bGsC5Cbm/giphy.gif)

# %% [markdown]
# ## **Overdoses**

# %%
import pandas as pd
data1 = pd.read_csv("data1.csv", sep=",")
amountInZip=dict()
for index, row in data1.iterrows():
    zip = row['incident_zip']
    if zip in amountInZip:
        amountInZip[zip]=amountInZip[zip]+1
    else:
        amountInZip[zip]=1
print(amountInZip)
# Out:
# {'15216': 179, '15215': 71, '15233': 20, '15236': 109, '15237': 87, '15137': 49, '15147': 84, '15136': 211, '15221': 168, '15044': 49, '15208': 70, '15132': 201, '15227': 164, '15207': 91, '15213': 50, '15135': 11, '15045': 49, '57108': 1, '15239': 53, '15210': 355, '15024': 33, '15148': 28, '15120': 136, '15241': 34, '15122': 87, '15226': 116, '15220': 69, '15068': 48, '15211': 117, '15107': 1, '15202': 128, '15104': 76, '15108': 125, '87124': 1, '15116': 32, '15146': 94, '15234': 65, '15106': 125, '15229': 52, '15201': 90, '16001': 6, '15145': 51, '15143': 34, '15321': 2, '15238': 32, '16160': 1, '15206': 148, '15203': 83, '15235': 186, '15065': 51, '15212': 282, '15224': 71, '15144': 19, '15232': 19, '15219': 153, '15034': 15, '15071': 27, '15112': 25, '15205': 144, '15223': 68, '16146': 2, '15225': 16, '33467': 1, '15666': 3, '15025': 98, '15204': 76, '15140': 41, '15243': 15, nan: 181, '16229': 1, '15101': 45, '15301': 14, '43920': 1, '28428': 1, '01220': 1, '15209': 78, '15222'
# ...

# %% [markdown]
# ## **Dog Licenses**

# %% [markdown]
# ![Dogs](https://media.giphy.com/media/Z9tvqoD1SEQcomTVaK/giphy.gif)

# %%
import pandas as pd
dataset = pd.read_csv("LifetimeDogLicenses.csv", sep=",")
amountInZip= dict()
for index, row in dataset.iterrows():
    zip = row['OwnerZip']
    
    if zip in amountInZip:
        amountInZip[zip] = amountInZip[zip] + 1
    else:
        amountInZip[zip] = 1
print(amountInZip)
# Out:
# {15137: 535, 15129: 533, 15140: 86, 15238: 529, 15037: 986, 15235: 1431, 15215: 386, 15236: 1765, 15221: 609, 15131: 546, 15065: 804, 15135: 367, 15202: 686, 15101: 1320, 15216: 389, 15132: 692, 15239: 1363, 15147: 862, 15146: 1258, 15108: 1506, 15044: 1436, 15139: 321, 15237: 2475, 15112: 75, 15120: 783, 15142: 65, 15227: 1296, 15220: 285, 15234: 483, 15122: 1344, 15071: 365, 15143: 1234, 15223: 297, 15136: 555, 15241: 913, 15102: 1453, 15229: 833, 15020: 28, 15024: 440, 15090: 1212, 15116: 684, 16046: 123, 15088: 33, 15218: 321, 15145: 183, 15332: 144, 15233: 6, 15106: 647, 15104: 89, 15209: 529, 15057: 309, 15084: 514, 15018: 60, 15228: 576, 15133: 551, 15035: 105, 15126: 251, 15205: 516, 15025: 952, 15144: 272, 15068: 382, 15045: 245, 15017: 527, 15049: 74, 15028: 11, 15243: 514, 15014: 160, 15076: 42, 15148: 60, 15006: 10, 15046: 109, 15214: 192, 15034: 125, 15110: 101, 15201: 8, 15047: 27, 15212: 98, 15210: 81, 15030: 37, 15127: 8, 15063: 118, 15668: 4, 15219: 14, 15051: 27, 15
# ...

# %% [markdown]
# ## **Private Schools**

# %%
import pandas as pd
data3 = pd.read_csv("data3.csv", sep=",")
numberOfSchools=dict()
for index, row in data3.iterrows():
    zip = row['location_zip_code']
    if zip in numberOfSchools:
        numberOfSchools[zip]=numberOfSchools[zip]+1
    else:
        numberOfSchools[zip]=1
print(numberOfSchools)
# Out:
# {15236: 5, 15220: 4, 15206: 14, 15233: 3, 15202: 9, 15227: 7, 15209: 2, 15212: 10, 15217: 9, 15221: 20, 15224: 4, 15102: 4, 15232: 5, 15025: 1, 15044: 6, 15132: 8, 15148: 1, 15110: 2, 15035: 1, 15218: 3, 15237: 11, 15205: 10, 15090: 12, 15116: 5, 15201: 3, 15238: 6, 15101: 5, 15222: 5, 15122: 4, 15213: 14, 15108: 8, 15210: 3, 15219: 6, 15024: 1, 15215: 3, 15235: 5, 15120: 7, 15239: 3, 15143: 8, 15226: 3, 15214: 5, 15261: 1, 16046: 1, 15147: 4, 15228: 7, 15146: 9, 15065: 4, 15136: 2, 15216: 4, 15129: 1, 15223: 1, 15131: 2, 15017: 4, 15241: 7, 15211: 1, 15243: 3, 15208: 3, 15137: 1, 15104: 1, 15139: 1, 15234: 1, 15207: 2, 15144: 1}

# %% [markdown]
# # **The Best Neighborhood**

# %% [markdown]
# ![Clapping](https://media.giphy.com/media/YRuFixSNWFVcXaxpmX/giphy.gif)

# %% [markdown]
# From our data, we believe the best neighborhood to live in is Plum which has zipcode 15239. We believe that is the best neighborhood because they have 1363 dog licenses. And only 53 overdoses, and 3 private schools. At first we were considering Plum and Gibsonia as the best neighborhoods but ended up going with Plum because it has a ratio of 1:.03:.002 and Gibsonia has a ratio of 1:.03:.004. As seen in the first chart below, most of the neighborhoods have over 300 overdoses, Plum has alomst 1/6 of that. As seen in the second chart below, a little less than half of the neighborhoods have less than 5 private schools, but most of those neighborhoods have higher overdoses and less dogs than Plum. As it can be seen in the 3rd chart below, there are some other towns that have as many dogs as Plum but we figured out that they have more overdoses and private schools than Plum. Lastly, 53 overdoses and 3 private schools may seem high for one town but as seen in the 4th chart below, those numbers are very small compared to the number of dogs, so the pros outweigh the cons.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
data1['incident_zip'].value_counts().plot.hist()

# %%
data = [{'Zip Code' : 15236, 'Number of Schools' : 5},{'Zip Code' : 15220, 'Number of Schools' : 4}, {'Zip Code' : 15206, 'Number of Schools' : 14}, {'Zip Code' : 15233, 'Number of Schools' : 3}, {'Zip Code' : 15202, 'Number of Schools' : 9}, {'Zip Code' : 15227, 'Number of Schools' : 7}, {'Zip Code' : 15209, 'Number of Schools' : 2}, {'Zip Code' : 15212, 'Number of Schools' : 10}, {'Zip Code' : 15217, 'Number of Schools' : 9}, {'Zip Code' : 15221, 'Number of Schools' : 20}, {'Zip Code' : 15224, 'Number of Schools' : 4}, {'Zip Code' : 15102, 'Number of Schools' : 4}, {'Zip Code' : 15232, 'Number of Schools' : 5}, {'Zip Code' : 15025, 'Number of Schools' : 1}, {'Zip Code' : 15044, 'Number of Schools' : 6}, {'Zip Code' : 15132, 'Number of Schools' : 8}, {'Zip Code' : 15148, 'Number of Schools' : 1}, {'Zip Code' : 15110, 'Number of Schools' : 2}, {'Zip Code' : 15035, 'Number of Schools' : 1}, {'Zip Code' : 15218, 'Number of Schools' : 3}, {'Zip Code' : 15237, 'Number of Schools' : 11}, {'Zip Code' : 15205, 'Number of Schools' : 10}, {'Zip Code' : 15090, 'Number of Schools' : 12}, {'Zip Code' : 15116, 'Number of Schools' : 5}, {'Zip Code' : 15201, 'Number of Schools' : 3}, {'Zip Code' : 15238, 'Number of Schools' : 6}, {'Zip Code' : 15101, 'Number of Schools' : 5}, {'Zip Code' : 15222, 'Number of Schools' : 5}, {'Zip Code' : 15122, 'Number of Schools' : 4}, {'Zip Code' : 15213, 'Number of Schools' : 14}, {'Zip Code' : 15108, 'Number of Schools' : 8}, {'Zip Code' : 15210, 'Number of Schools' : 3}, {'Zip Code' : 15219, 'Number of Schools' : 6}, {'Zip Code' : 15024, 'Number of Schools' : 1}, {'Zip Code' : 15215, 'Number of Schools' : 3}, {'Zip Code' : 15235, 'Number of Schools' : 5}, {'Zip Code' : 15120, 'Number of Schools' : 7}, {'Zip Code' : 15239, 'Number of Schools' : 3}, {'Zip Code' : 15143, 'Number of Schools' : 8}, {'Zip Code' : 15226, 'Number of Schools' : 3}, {'Zip Code' : 15214, 'Number of Schools' : 5}, {'Zip Code' : 15261, 'Number of Schools' : 1}, {'Zip Code' : 16046, 'Number of Schools' : 1}, {'Zip Code' : 15147, 'Number of Schools' : 4}, {'Zip Code' : 15228, 'Number of Schools' : 7}, {'Zip Code' : 15146, 'Number of Schools' : 9}, {'Zip Code' : 15065, 'Number of Schools' : 4}, {'Zip Code' : 15136, 'Number of Schools' : 2}, {'Zip Code' : 15216, 'Number of Schools' : 4}, {'Zip Code' : 15129, 'Number of Schools' : 1}, {'Zip Code' : 15223, 'Number of Schools' : 1}, {'Zip Code' : 15131, 'Number of Schools' : 2}, {'Zip Code' : 15017, 'Number of Schools' : 4}, {'Zip Code' : 15241, 'Number of Schools' : 7}, {'Zip Code' : 15211, 'Number of Schools' : 1}, {'Zip Code' : 15243, 'Number of Schools' : 3}, {'Zip Code' : 15208, 'Number of Schools' : 3}, {'Zip Code' : 15137, 'Number of Schools' : 1}, {'Zip Code' : 15104, 'Number of Schools' : 1}, {'Zip Code' : 15139, 'Number of Schools' : 1}, {'Zip Code' : 15234, 'Number of Schools' : 1}, {'Zip Code' : 15207, 'Number of Schools' : 2}, {'Zip Code' : 15144, 'Number of Schools' : 1} ]
new = pd.DataFrame.from_dict(data)
graph = new.plot.bar(x="Zip Code", y="Number of Schools", figsize=(15, new.shape[0] * 0.3), legend=None)
graph.set_xlabel("ZipCode")
graph.set_xlabel("Number of Private Schools")
# Out:
# Text(0.5, 0, 'Number of Private Schools')

# %%
import pandas as pd
data = [{'Zip Code': 15137, '# of Dogs Licensed': 535}, {'Zip Code': 15129, '# of Dogs Licensed': 533}, {'Zip Code': 15140, '# of Dogs Licensed': 86}, {'Zip Code': 15238, '# of Dogs Licensed': 529}, {'Zip Code': 15037, '# of Dogs Licensed': 986}, {'Zip Code': 15235,'# of Dogs Licensed': 1431}, {'Zip Code': 15215, '# of Dogs Licensed': 386}, {'Zip Code': 15236, '# of Dogs Licensed': 1765}, {'Zip Code': 15221, '# of Dogs Licensed': 609}, {'Zip Code': 15131, '# of Dogs Licensed': 546}, {'Zip Code': 15065, '# of Dogs Licensed': 804}, {'Zip Code': 15135, '# of Dogs Licensed': 367}, {'Zip Code': 15202, '# of Dogs Licensed': 686}, {'Zip Code': 15101, '# of Dogs Licensed': 1320}, {'Zip Code': 15216, '# of Dogs Licensed': 389}, {'Zip Code': 15132, '# of Dogs Licensed': 692}, {'Zip Code': 15239, '# of Dogs Licensed': 1363}, {'Zip Code': 15147, '# of Dogs Licensed': 862}, {'Zip Code': 15146, '# of Dogs Licensed': 1258}, {'Zip Code': 15108, '# of Dogs Licensed': 1506}, {'Zip Code': 15044, '# of Dogs Licensed': 1436}, {'Zip Code': 15139, '# of Dogs Licensed': 321}, {'Zip Code': 15237, '# of Dogs Licensed': 2475}, {'Zip Code': 15112, '# of Dogs Licensed': 75}, {'Zip Code': 15120, '# of Dogs Licensed': 783}, {'Zip Code': 15142, '# of Dogs Licensed': 65}, {'Zip Code': 15227, '# of Dogs Licensed': 1296}, {'Zip Code': 15220, '# of Dogs Licensed': 285}, {'Zip Code': 15234, '# of Dogs Licensed': 483}, {'Zip Code': 15122, '# of Dogs Licensed': 1344}, {'Zip Code': 15071, '# of Dogs Licensed': 365}, {'Zip Code': 15143, '# of Dogs Licensed': 1234}, {'Zip Code': 15223, '# of Dogs Licensed': 297}, {'Zip Code': 15136, '# of Dogs Licensed': 555}, {'Zip Code': 15241, '# of Dogs Licensed': 913}, {'Zip Code': 15102, '# of Dogs Licensed': 1453}, {'Zip Code': 15229, '# of Dogs Licensed': 833}, {'Zip Code': 15020, '# of Dogs Licensed': 28}, {'Zip Code': 15024, '# of Dogs Licensed': 440}, {'Zip Code': 15090, '# of Dogs Licensed': 1212}, {'Zip Code': 15116, '# of Dogs Licensed': 684}, {'Zip Code': 16046, '# of Dogs Licensed': 123}, {'Zip Code': 15088, '# of Dogs Licensed': 33}, {'Zip Code': 15218, '# of Dogs Licensed': 321}, {'Zip Code': 15145, '# of Dogs Licensed': 183}, {'Zip Code': 15332, '# of Dogs Licensed': 144}, {'Zip Code': 15233, '# of Dogs Licensed': 6}, {'Zip Code': 15106, '# of Dogs Licensed': 647}, {'Zip Code': 15104, '# of Dogs Licensed': 89}, {'Zip Code': 15209, '# of Dogs Licensed': 529}, {'Zip Code': 15057, '# of Dogs Licensed': 309}, {'Zip Code': 15084, '# of Dogs Licensed': 514}, {'Zip Code': 15018, '# of Dogs Licensed': 60}, {'Zip Code': 15228, '# of Dogs Licensed': 576}, {'Zip Code': 15133, '# of Dogs Licensed': 551}, {'Zip Code': 15035, '# of Dogs Licensed': 105}, {'Zip Code': 15126, '# of Dogs Licensed': 251}, {'Zip Code': 15205, '# of Dogs Licensed': 516}, {'Zip Code': 15025, '# of Dogs Licensed': 952}, {'Zip Code': 15144, '# of Dogs Licensed': 272}, {'Zip Code': 15068, '# of Dogs Licensed': 382}, {'Zip Code': 15045, '# of Dogs Licensed': 245}, {'Zip Code': 15017, '# of Dogs Licensed': 527}, {'Zip Code': 15049, '# of Dogs Licensed': 74}, {'Zip Code': 15028, '# of Dogs Licensed': 11}, {'Zip Code': 15028, '# of Dogs Licensed': 11}, {'Zip Code': 15243, '# of Dogs Licensed': 514}, {'Zip Code': 15014, '# of Dogs Licensed': 160}, {'Zip Code': 15076, '# of Dogs Licensed': 42}, {'Zip Code': 15148, '# of Dogs Licensed': 60}, {'Zip Code': 15006, '# of Dogs Licensed': 10}, {'Zip Code': 15046, '# of Dogs Licensed': 109}, {'Zip Code': 15214, '# of Dogs Licensed': 192}, {'Zip Code': 15034, '# of Dogs Licensed': 125}, {'Zip Code': 15110, '# of Dogs Licensed': 101}, {'Zip Code': 15201, '# of Dogs Licensed': 8}, {'Zip Code': 15047, '# of Dogs Licensed': 27}, {'Zip Code': 15212, '# of Dogs Licensed': 98}, {'Zip Code': 15210, '# of Dogs Licensed': 81}, {'Zip Code': 15030, '# of Dogs Licensed': 37}, {'Zip Code': 15127, '# of Dogs Licensed': 8}, {'Zip Code': 15063, '# of Dogs Licensed': 118}, {'Zip Code': 15668, '# of Dogs Licensed': 4}, {'Zip Code': 15219, '# of Dogs Licensed': 14}, {'Zip Code': 15051, '# of Dogs Licensed': 27}, {'Zip Code': 15085, '# of Dogs Licensed': 8}, {'Zip Code': 15086, '# of Dogs Licensed': 25}, {'Zip Code': 15056, '# of Dogs Licensed': 31}, {'Zip Code': 15208, '# of Dogs Licensed': 8}, {'Zip Code': 15003, '# of Dogs Licensed': 34}, {'Zip Code': 15083, '# of Dogs Licensed': 7}, {'Zip Code': 15225, '# of Dogs Licensed': 31}, {'Zip Code': 15206, '# of Dogs Licensed': 8}, {'Zip Code': 15330, '# of Dogs Licensed': 1}, {'Zip Code': 15015, '# of Dogs Licensed': 72}, {'Zip Code': 15005, '# of Dogs Licensed': 53}, {'Zip Code': 15026, '# of Dogs Licensed': 57}, {'Zip Code': 15207, '# of Dogs Licensed': 12}, {'Zip Code': 15222, '# of Dogs Licensed': 4}, {'Zip Code': 15226, '# of Dogs Licensed': 45}, {'Zip Code': 15642, '# of Dogs Licensed': 7}, {'Zip Code': 15007, '# of Dogs Licensed': 10}, {'Zip Code': 15224, '# of Dogs Licensed': 3}, {'Zip Code': 16066, '# of Dogs Licensed': 1}, {'Zip Code': 15075, '# of Dogs Licensed': 22}, {'Zip Code': 15217, '# of Dogs Licensed': 15}, {'Zip Code': 15213, '# of Dogs Licensed': 2}, {'Zip Code': 15203, '# of Dogs Licensed': 6}, {'Zip Code': 15626, '# of Dogs Licensed': 1}, {'Zip Code': 16059, '# of Dogs Licensed': 17}, {'Zip Code': 15012, '# of Dogs Licensed': 4}, {'Zip Code': 15064, '# of Dogs Licensed': 8}, {'Zip Code': 33426, '# of Dogs Licensed': 1}, {'Zip Code': 15232, '# of Dogs Licensed': 6}, {'Zip Code': 47909, '# of Dogs Licensed': 1}, {'Zip Code': 46845, '# of Dogs Licensed': 1}, {'Zip Code': 15031, '# of Dogs Licensed': 8}, {'Zip Code': 15091, '# of Dogs Licensed': 1}, {'Zip Code': 15204, '# of Dogs Licensed': 1}, {'Zip Code': 15082, '# of Dogs Licensed': 5}, {'Zip Code': 15095, '# of Dogs Licensed': 1}, {'Zip Code': 15230, '# of Dogs Licensed': 1}, {'Zip Code': 15275, '# of Dogs Licensed': 1}, {'Zip Code': 15089, '# of Dogs Licensed': 1}, {'Zip Code': 16342, '# of Dogs Licensed': 1}, {'Zip Code': 15211, '# of Dogs Licensed': 4}, {'Zip Code': 15681, '# of Dogs Licensed': 1}, {'Zip Code': 16229, '# of Dogs Licensed': 5}, {'Zip Code': 15601, '# of Dogs Licensed': 1}, {'Zip Code': 32081, '# of Dogs Licensed': 1}, {'Zip Code': 15321, '# of Dogs Licensed': 1},] 
new = pd.DataFrame.from_dict(data) 
graph = new.plot.bar(x="Zip Code", y="# of Dogs Licensed", figsize=(70,new.shape[0] * 0.3), legend=None)
graph.set_xlabel("Zip Code", size=60)
graph.set_ylabel("# of Licensed Dogs", size=60)
graph.set_title('Dogs in each Pittsburgh Zipcode', size=80)
# Out:
# Text(0.5, 1.0, 'Dogs in each Pittsburgh Zipcode')

# %%
import pandas as pd
df = pd.DataFrame({'15239':['Drug OverDoses', 'Dog Licenses', 'Private Schools'], 'amount':[53, 1363, 3]})
ax = df.plot.bar(x='15239', y='amount', rot=0)

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ## **Ava**

# %% [markdown]
# Even though there were neighborhoods that had higher amounts of dogs, or lower levels of overdoses, or less amounts of private schools, I still agree with the data that Plum is the best because it has the best ratio for all the neighborhoods by being 1363:53:3. I personally am not from Pittsburgh so I have only been to Oakland and Shady Side. Even though I believe the friendliest neighborhood is Plum because I trust our data, my favorite neighborhood is still Shady Side. It is my favorite because I enjoy going to a coffee shop there to sit and do some work. Maybe I would enjoy Plum too but I cannot say for sure since I have never been there.

# %% [markdown]
# ## **Torrie**

# %% [markdown]
# I agree with the data of number of dogs, levels of overdoses, and number of private schools because I am local to the Pittsburgh area and have a decent idea of each neighborhood. Plum having the most positive aspects overall is fascinating to me because I actually grew up there! However, my favorite neighborhood in Pittsburgh is Oakmont because there is a multitude of cute coffee shops, small movie theatres, and beautiful, walkable nature-filled spaces.
